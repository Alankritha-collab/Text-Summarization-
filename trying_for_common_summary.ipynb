# %%
from googlesearch import search

# %%
from goose3 import Goose
from googlesearch import search
import nltk
from nltk.stem import WordNetLemmatizer
import string 
import re

# %%
query = input("enter your query:")
l1=[]
for i in search(query, tld="com",num=10,stop=15, pause=2):
    print(i)
    l1.append(i)
g = Goose()
print(l1)
# Out:
# enter your query:text summarizaion
# https://quillbot.com/summarize
# https://www.topcoder.com/thrive/articles/text-summarization-in-nlp
# https://blog.floydhub.com/gentle-introduction-to-text-summarization-in-machine-learning/
# https://www.paraphraser.io/text-summarizer
# https://www.analyticsvidhya.com/blog/2022/02/text-summarisation/
# https://www.analyticsvidhya.com/blog/2019/06/comprehensive-guide-text-summarization-using-deep-learning-python/
# https://medium.com/luisfredgs/automatic-text-summarization-with-machine-learning-an-overview-68ded5717a25
# https://en.wikipedia.org/wiki/Automatic_summarization
# https://towardsdatascience.com/a-quick-introduction-to-text-summarization-in-machine-learning-3d27ccf18a9f
# https://paperswithcode.com/task/text-summarization
# https://www.mygreatlearning.com/blog/text-summarization-in-python/
# https://resoomer.com/en/
# https://deepai.org/machine-learning-model/summarization
# ...

# %%
g=Goose()
print("enter the index of your link")
val=int(input())
url=l1[val]
print(url)
article = g.extract(url)
article.cleaned_text
# Out:
# enter the index of your link
# 4
# https://towardsdatascience.com/a-quick-introduction-to-text-summarization-in-machine-learning-3d27ccf18a9f
# ...

# %%
# %store url
# Out:
# Stored 'url' (str)

# %%
# %store -r summary_1

# %%
summary_1
# Out:
# 'Skyhoshi, who is a U.S.-based machine learning expert with 13 years of experience and currently teaches people his skills, says that “the technique has proved to be critical in quickly and accurately summarizing voluminous texts, something which could be expensive and time consuming if done without machines.”\n\nMachine learning models are usually trained to understand documents and distill the useful information before outputting the required summarized texts. There are two main types of how to summarize text in NLP:\n\nThe extractive text summarization technique involves pulling keyphrases from the source document and combining them to make a summary. The abstractive text summarization algorithms create new phrases and sentences that relay the most useful information from the original text — just like humans do. Usually, text summarization in NLP is treated as a supervised machine learning problem (where future outcomes are predicted based on provided data). Text summarization ref
# ...

# %%
# %store -r summary_2

# %%
print(summary_2)
# Out:
# There are two main types of how to summarize text in NLP:
#
# The extractive text summarization technique involves pulling keyphrases from the source document and combining them to make a summary. 3. Text summarization refers to the technique of shortening long pieces of text. As you can see above, the words in bold have been extracted and joined to create a summary — although sometimes the summary can be grammatically strange. Typically, here is how using the extraction-based approach to summarize texts can work:
#
# 1. The keyphrases should be compatible to the stipulated extraction technique. The abstraction technique entails paraphrasing and shortening parts of the source document. Here is an example:
#
# ...

# %%
# %store -r summary_3

# %%
print(summary_3)
# Out:
# Text summarization refers to the technique of shortening long pieces of text. Automatic text summarization is a common problem in machine learning and natural language processing (NLP). What’s the need for text summarization? That’s a lot of data! With such a big amount of data circulating in the digital space, there is need to develop machine learning algorithms that can automatically shorten longer texts and deliver accurate summaries that can fluently pass the intended messages. Furthermore, applying text summarization reduces reading time, accelerates the process of researching for information, and increases the amount of information that can fit in an area. What are the main approaches to automatic summarization? There are two main types of how to summarize text in NLP: The extractive text summarization technique involves pulling keyphrases from the source document and combining them to make a summary. Here is an example: Source text: Joseph and Mary rode on a donkey to attend t
# ...

# %%
# %store -r summary_4_string

# %%
print(summary_4_string)
# Out:
# Text summarization refers to the technique of shortening long pieces of text. As research in this area continues, we can expect to see breakthroughs that will assist in fluently and accurately shortening long text documents. What’s the need for text summarization?
#
# Propelled by the modern technological innovations, data is to this century what oil was to the previous one. Furthermore, applying text summarization reduces reading time, accelerates the process of researching for information, and increases the amount of information that can fit in an area. When abstraction is applied for text summarization in deep learning problems, it can overcome the grammar inconsistencies of the extractive method.
#
# Usually, text summarization in NLP is treated as a supervised machine learning problem (where future outcomes are predicted based on provided data).
#
# ...

# %%
common_summary =' '
for summary in summary_1:
    if summary in summary_2 and summary_3 and summary_4_string:
        common_summary += '' +summary

# %%
from IPython.core.display import HTML 
import speech_recognition as sr
from gtts import gTTS
from IPython.display import Audio

# %%
display(HTML(f""" {common_summary}"""))
tts= gTTS(common_summary)
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#   Skyhoshi, who is a .S.-based machine learning expert with 13 years of experience and currently teaches people his skills, says that the technique has proved to be critical in quickly and accurately summarizing voluminous texts, something which could be expensive and time consuming if done without machines.
#
# Machine learning models are usually trained to understand documents and distill the useful information before outputting the required summarized texts. There are two main types of how to summarize text in NLP:
#
# ...

# %%
# %store common_summary
# Out:
# Stored 'common_summary' (str)
